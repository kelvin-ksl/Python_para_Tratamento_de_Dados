# %% [markdown]
# # Atividade de Pandas -
# #### Conteúdo:
# - Leitura de Dados
# - Manipulação de Index

# %% [markdown]
# **1) Baixe o dataset de veículos na sua máquina e faça a leitura de dados usando link https://www.kaggle.com/datasets/nehalbirla/vehicle-dataset-from-cardekho**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('car data.csv')
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df = df.drop(["Car_Name"] ,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 df = df.drop(["Car_Name" == 'wagon r'], axis=1)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %% [markdown]
# **2) Crie uma nova coluna no seu dataframe que apresenta o número atual da posição do registro, iniciando pelo número 0**

# %%
df['Posição'] = df.index
print(df)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  index  Posição
# 0        Dealer       Manual      0      0        0
# ...

# %% [markdown]
# **3) Set o index usando o name do veículo**

# %%
#df.set_index('Car_Name', inplace=True)
df
# Out:
#           Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# Car_Name
# ritz      2014           3.35           5.59       27000    Petrol
# sx4       2013           4.75           9.54       43000    Diesel
# ciaz      2017           7.25           9.85        6900    Petrol
# wagon r   2011           2.85           4.15        5200    Petrol
# swift     2014           4.60           6.87       42450    Diesel
# ...        ...            ...            ...         ...       ...
# city      2016           9.50          11.60       33988    Diesel
# brio      2015           4.00           5.90       60000    Petrol
# city      2009           3.35          11.00       87934    Petrol
# city      2017          11.50          12.50        9000    Diesel
# brio      2016           5.30           5.90        5464    Petrol
#
#          Seller_Type Transmission  Owner  index  Posição
# Car_Name
# ritz          Dealer       Manual      0      0        0
# ...

# %% [markdown]
# **4) Imprima o dataframe sem os índices**

# %%
df.reset_index(inplace=True)
df
# Out:
#      level_0 Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0          0     ritz  2014           3.35           5.59       27000
# 1          1      sx4  2013           4.75           9.54       43000
# 2          2     ciaz  2017           7.25           9.85        6900
# 3          3  wagon r  2011           2.85           4.15        5200
# 4          4    swift  2014           4.60           6.87       42450
# ..       ...      ...   ...            ...            ...         ...
# 296      296     city  2016           9.50          11.60       33988
# 297      297     brio  2015           4.00           5.90       60000
# 298      298     city  2009           3.35          11.00       87934
# 299      299     city  2017          11.50          12.50        9000
# 300      300     brio  2016           5.30           5.90        5464
#
#     Fuel_Type Seller_Type Transmission  Owner  index  Posição
# 0      Petrol      Dealer       Manual      0      0        0
# ...

# %% [markdown]
# **5) Salve os 20 primeiros registros do dataframe em um arquivo JSON**

# %%
df.loc[0:19].to_json('file.json')

# %%
teste = pd.read_json('file.json')
teste
# Out:
#     level_0       Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0         0           ritz  2014           3.35           5.59       27000
# 1         1            sx4  2013           4.75           9.54       43000
# 2         2           ciaz  2017           7.25           9.85        6900
# 3         3        wagon r  2011           2.85           4.15        5200
# 4         4          swift  2014           4.60           6.87       42450
# 5         5  vitara brezza  2018           9.25           9.83        2071
# 6         6           ciaz  2015           6.75           8.12       18796
# 7         7        s cross  2015           6.50           8.61       33429
# 8         8           ciaz  2016           8.75           8.89       20273
# 9         9           ciaz  2015           7.45           8.92       42367
# 10       10       alto 800  2017           2.85           3.60        2135
# ...
