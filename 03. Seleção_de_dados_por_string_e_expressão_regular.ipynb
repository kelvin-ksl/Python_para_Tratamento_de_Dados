# %% [markdown]
# # String e Expressões regulares
# - 1. Trabalhando com Regex
# - 2. Seleção de Dados em dados de String
#
#
#
# #### Contexto
# No dia a dia de trabalho do cientista de dados você pode precisar buscar um dataset que contém padrões de Strings.
# Você pode usar a lib "re" para buscar por padrões de string, como por exemplo:
# - Nomes começando com um caractere específico
# - Pesquisar um padrão dentro de uma coluna de dataframe
# - Extrair tipos de dados de um texto (datas).
#
# Aqui estão as funções do pandas que aceitam expressão regular:

# %% [markdown]
# - Links Importantes
#     - https://kanoki.org/2019/11/12/how-to-use-regex-in-pandas/
#     - https://docs.python.org/3/howto/regex.html

# %% [markdown]
# #### Roteiro
# - 1. Trabalhando com regex
# - 2. Seleção de Dados usando String

# %%
##### bibliotecas usadas
import pandas as pd
import re

# %% [markdown]
# ## 1. Trabalhando com Regex
#
# - pegando elementos que não são dígitos \D
# - Verificar se o e-mail é correto
# - Verificações de dados usando Series

# %% [markdown]
# **Inicia com um texto e termina com Spain**

# %%
txt = "The rain in Brazil"
patter = "^rain"

if re.search(patter, txt):
    print('Texto ok')
else:
    print('Texto inválido')
# Out:
# Texto inválido

# %% [markdown]
# **Validando email**
# - Padrões gerais
#     - Uppercase - [A-Z]
#     - lowecase - [a-z]
#     - numbers - [0-9]

# %%
mascara_digitos = '^[A-Z]'
nome = 'nicksson'

if(re.search(mascara_digitos, nome)):
    print('Nome Correto')
else:
    print('Nome Inválido')
# Out:
# Nome Inválido

# %%
mascara_numeros = '^[0-9]'
digitos = 'a98989'

if(re.search(mascara_numeros, digitos)):
    print('digitos Correto')
else:
    print('digitos Inválido')
# Out:
# digitos Inválido

# %%
"palavra e número"@"palavra".("com")
# Out:
#   File "C:\Users\nicksson.a\AppData\Local\Temp/ipykernel_7684/645989717.py", line 1
#     "palavra e número"@"palavra".("com")
#                                  ^
# SyntaxError: invalid syntax

# %%
mascara_email = "[a-zA-Z0-9]+@[a-zA-Z]+\.(com|edu|net)"

email = "nicksson9898@hotmail.com"

if(re.search(mascara_email, email)):
    print('Email Correto')
else:
    print('Email Inválido')
# Out:
# Email Correto

# %% [markdown]
# ### 2. Seleção de Dados por String

# %%
df = pd.read_csv('data/titanic.csv')

# %% [markdown]
# ### Seleção de Dados
# - Seleção usando loc e iloc
# - Seleção de dados por condicional
# - seleção de dados por tipos

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
df[df['Name'].str.contains('Mr.')]
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 3               4       1.0       1
# 4               5       0.0       3
# 5               6       0.0       3
# ...           ...       ...     ...
# 1298         1299       NaN       1
# 1302         1303       NaN       1
# 1304         1305       NaN       3
# 1306         1307       NaN       3
# 1307         1308       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# 5                                      Moran, Mr. James    male   NaN      0
# ...                                                 ...     ...   ...    ...
# 1298                         Widener, Mr. George Dunton    male  50.0      1
# 1302    Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 1304                                 Spector, Mr. Woolf    male   NaN      0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 1307                                Ware, Mr. Frederick    male   NaN      0
#
#       Parch              Ticket      Fare Cabin Embarked
# 0         0           A/5 21171    7.2500   NaN        S
# 1         0            PC 17599   71.2833   C85        C
# 3         0              113803   53.1000  C123        S
# 4         0              373450    8.0500   NaN        S
# 5         0              330877    8.4583   NaN        Q
# ...     ...                 ...       ...   ...      ...
# 1298      1              113503  211.5000   C80        C
# 1302      0               19928   90.0000   C78        Q
# 1304      0           A.5. 3236    8.0500   NaN        S
# 1306      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307      0              359309    8.0500   NaN        S
#
# [959 rows x 12 columns]

# %%
df[df['Name'].str.contains('Mr.|Miss')]
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1302         1303       NaN       1
# 1303         1304       NaN       3
# 1304         1305       NaN       3
# 1306         1307       NaN       3
# 1307         1308       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...                                                 ...     ...   ...    ...
# 1302    Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 1303                     Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 1304                                 Spector, Mr. Woolf    male   NaN      0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 1307                                Ware, Mr. Frederick    male   NaN      0
#
#       Parch              Ticket     Fare Cabin Embarked
# 0         0           A/5 21171   7.2500   NaN        S
# 1         0            PC 17599  71.2833   C85        C
# 2         0    STON/O2. 3101282   7.9250   NaN        S
# 3         0              113803  53.1000  C123        S
# 4         0              373450   8.0500   NaN        S
# ...     ...                 ...      ...   ...      ...
# 1302      0               19928  90.0000   C78        Q
# 1303      0              347086   7.7750   NaN        S
# 1304      0           A.5. 3236   8.0500   NaN        S
# 1306      0  SOTON/O.Q. 3101262   7.2500   NaN        S
# 1307      0              359309   8.0500   NaN        S
#
# [1217 rows x 12 columns]

# %%
df[df['Name'].str.contains('Allen')]
# Out:
#       PassengerId  Survived  Pclass  \
# 4               5       0.0       3
# 730           731       1.0       1
# 1069         1070       NaN       2
#
#                                                   Name     Sex   Age  SibSp  \
# 4                             Allen, Mr. William Henry    male  35.0      0
# 730                      Allen, Miss. Elisabeth Walton  female  29.0      0
# 1069  Becker, Mrs. Allen Oliver (Nellie E Baumgardner)  female  36.0      0
#
#       Parch  Ticket      Fare Cabin Embarked
# 4         0  373450    8.0500   NaN        S
# 730       0   24160  211.3375    B5        S
# 1069      3  230136   39.0000    F4        S

# %%
df[df['Name'].str.contains('^Allen')]
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 4              5       0.0       3       Allen, Mr. William Henry    male
# 730          731       1.0       1  Allen, Miss. Elisabeth Walton  female
#
#       Age  SibSp  Parch  Ticket      Fare Cabin Embarked
# 4    35.0      0      0  373450    8.0500   NaN        S
# 730  29.0      0      0   24160  211.3375    B5        S

# %%
df[df['Name'].str.contains('Henry$')]
# Out:
#       PassengerId  Survived  Pclass                             Name   Sex  \
# 4               5       0.0       3         Allen, Mr. William Henry  male
# 12             13       0.0       3   Saundercock, Mr. William Henry  male
# 159           160       0.0       3       Sage, Master. Thomas Henry  male
# 209           210       1.0       1                 Blank, Mr. Henry  male
# 212           213       0.0       3           Perkin, Mr. John Henry  male
# 222           223       0.0       3          Green, Mr. George Henry  male
# 239           240       0.0       2           Hunt, Mr. George Henry  male
# 271           272       1.0       3     Tornquist, Mr. William Henry  male
# 385           386       0.0       2        Davies, Mr. Charles Henry  male
# 411           412       0.0       3                  Hart, Mr. Henry  male
# 476           477       0.0       2          Renouf, Mr. Peter Henry  male
# 482           483       0.0       3         Rouse, Mr. Richard Henry  male
# 594           595       0.0       2          Chapman, Mr. John Henry  male
# 695           696       0.0       2       Chapman, Mr. Charles Henry  male
# 722           723       0.0       2     Gillespie, Mr. William Henry  male
# 949           950       NaN       3        Davison, Mr. Thomas Henry  male
# 990           991       NaN       3     Nancarrow, Mr. William Henry  male
# 1037         1038       NaN       1      Hilliard, Mr. Herbert Henry  male
# 1068         1069       NaN       1  Stengel, Mr. Charles Emil Henry  male
# 1251         1252       NaN       3      Sage, Master. William Henry  male
# 1290         1291       NaN       3         Conlon, Mr. Thomas Henry  male
#
#        Age  SibSp  Parch        Ticket     Fare Cabin Embarked
# 4     35.0      0      0        373450   8.0500   NaN        S
# 12    20.0      0      0     A/5. 2151   8.0500   NaN        S
# 159    NaN      8      2      CA. 2343  69.5500   NaN        S
# 209   40.0      0      0        112277  31.0000   A31        C
# 212   22.0      0      0     A/5 21174   7.2500   NaN        S
# 222   51.0      0      0         21440   8.0500   NaN        S
# 239   33.0      0      0    SCO/W 1585  12.2750   NaN        S
# 271   25.0      0      0          LINE   0.0000   NaN        S
# 385   18.0      0      0  S.O.C. 14879  73.5000   NaN        S
# 411    NaN      0      0        394140   6.8583   NaN        Q
# 476   34.0      1      0         31027  21.0000   NaN        S
# 482   50.0      0      0      A/5 3594   8.0500   NaN        S
# 594   37.0      1      0   SC/AH 29037  26.0000   NaN        S
# 695   52.0      0      0        248731  13.5000   NaN        S
# 722   34.0      0      0         12233  13.0000   NaN        S
# 949    NaN      1      0        386525  16.1000   NaN        S
# 990   33.0      0      0    A./5. 3338   8.0500   NaN        S
# 1037   NaN      0      0         17463  51.8625   E46        S
# 1068  54.0      1      0         11778  55.4417  C116        C
# 1251  14.5      8      2      CA. 2343  69.5500   NaN        S
# 1290  31.0      0      0         21332   7.7333   NaN        Q

# %%
df[df['Name'].str.contains('^Allen.*Henry$')]
# Out:
#    PassengerId  Survived  Pclass                      Name   Sex   Age  SibSp  \
# 4            5       0.0       3  Allen, Mr. William Henry  male  35.0      0
#
#    Parch  Ticket  Fare Cabin Embarked
# 4      0  373450  8.05   NaN        S

# %%
## Filter nomes que começam com uma letra OU terminam com outra letra
df[df['Name'].str.contains('^A|y$')]
# Out:
#       PassengerId  Survived  Pclass  \
# 4               5       0.0       3
# 12             13       0.0       3
# 13             14       0.0       3
# 25             26       1.0       3
# 40             41       0.0       3
# ...           ...       ...     ...
# 1281         1282       NaN       1
# 1283         1284       NaN       3
# 1290         1291       NaN       3
# 1292         1293       NaN       2
# 1297         1298       NaN       2
#
#                                                    Name     Sex   Age  SibSp  \
# 4                              Allen, Mr. William Henry    male  35.0      0
# 12                       Saundercock, Mr. William Henry    male  20.0      0
# 13                          Andersson, Mr. Anders Johan    male  39.0      1
# 25    Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 40       Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# ...                                                 ...     ...   ...    ...
# 1281                         Payne, Mr. Vivian Ponsonby    male  23.0      0
# 1283                      Abbott, Master. Eugene Joseph    male  13.0      0
# 1290                           Conlon, Mr. Thomas Henry    male  31.0      0
# 1292                                    Gale, Mr. Harry    male  38.0      1
# 1297                          Ware, Mr. William Jeffery    male  23.0      1
#
#       Parch     Ticket     Fare Cabin Embarked
# 4         0     373450   8.0500   NaN        S
# 12        0  A/5. 2151   8.0500   NaN        S
# 13        5     347082  31.2750   NaN        S
# 25        5     347077  31.3875   NaN        S
# 40        0       7546   9.4750   NaN        S
# ...     ...        ...      ...   ...      ...
# 1281      0      12749  93.5000   B24        S
# 1283      2  C.A. 2673  20.2500   NaN        S
# 1290      0      21332   7.7333   NaN        Q
# 1292      0      28664  21.0000   NaN        S
# 1297      0      28666  10.5000   NaN        S
#
# [130 rows x 12 columns]

# %%
## Todos os tikcer que só começam com números
df[df['Ticket'].str.contains('^[0-9]')]
# Out:
#       PassengerId  Survived  Pclass  \
# 3               4       1.0       1
# 4               5       0.0       3
# 5               6       0.0       3
# 6               7       0.0       1
# 7               8       0.0       3
# ...           ...       ...     ...
# 1301         1302       NaN       3
# 1302         1303       NaN       1
# 1303         1304       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                  Name     Sex   Age  SibSp  \
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# ...                                               ...     ...   ...    ...
# 1301                           Naughton, Miss. Hannah  female   NaN      0
# 1302  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 1303                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 1307                              Ware, Mr. Frederick    male   NaN      0
# 1308                         Peter, Master. Michael J    male   NaN      1
#
#       Parch  Ticket     Fare Cabin Embarked
# 3         0  113803  53.1000  C123        S
# 4         0  373450   8.0500   NaN        S
# 5         0  330877   8.4583   NaN        Q
# 6         0   17463  51.8625   E46        S
# 7         1  349909  21.0750   NaN        S
# ...     ...     ...      ...   ...      ...
# 1301      0  365237   7.7500   NaN        Q
# 1302      0   19928  90.0000   C78        Q
# 1303      0  347086   7.7750   NaN        S
# 1307      0  359309   8.0500   NaN        S
# 1308      1    2668  22.3583   NaN        C
#
# [957 rows x 12 columns]

# %%
## string que começa com vogais a-z ou A-Z
df[df['Ticket'].str.contains('^[A-Z]')]
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 10             11       1.0       3
# 12             13       0.0       3
# ...           ...       ...     ...
# 1296         1297       NaN       2
# 1300         1301       NaN       3
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 10                      Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 12                       Saundercock, Mr. William Henry    male  20.0      0
# ...                                                 ...     ...   ...    ...
# 1296       Nourney, Mr. Alfred (Baron von Drachstedt")"    male  20.0      0
# 1300                          Peacock, Miss. Treasteall  female   3.0      1
# 1304                                 Spector, Mr. Woolf    male   NaN      0
# 1305                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5      0
#
#       Parch              Ticket      Fare Cabin Embarked
# 0         0           A/5 21171    7.2500   NaN        S
# 1         0            PC 17599   71.2833   C85        C
# 2         0    STON/O2. 3101282    7.9250   NaN        S
# 10        1             PP 9549   16.7000    G6        S
# 12        0           A/5. 2151    8.0500   NaN        S
# ...     ...                 ...       ...   ...      ...
# 1296      0       SC/PARIS 2166   13.8625   D38        C
# 1300      1  SOTON/O.Q. 3101315   13.7750   NaN        S
# 1304      0           A.5. 3236    8.0500   NaN        S
# 1305      0            PC 17758  108.9000  C105        C
# 1306      0  SOTON/O.Q. 3101262    7.2500   NaN        S
#
# [352 rows x 12 columns]

# %%
## String que não contém números
df[df['Ticket'].str.contains('[0-9]')==False]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 179          180       0.0       3              Leonard, Mr. Lionel  male
# 271          272       1.0       3     Tornquist, Mr. William Henry  male
# 302          303       0.0       3  Johnson, Mr. William Cahoone Jr  male
# 597          598       0.0       3              Johnson, Mr. Alfred  male
#
#       Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 179  36.0      0      0   LINE   0.0   NaN        S
# 271  25.0      0      0   LINE   0.0   NaN        S
# 302  19.0      0      0   LINE   0.0   NaN        S
# 597  49.0      0      0   LINE   0.0   NaN        S

# %% [markdown]
# ### Mundando valores de string

# %%
df[df['Name'].str.contains('Henry$')].head()
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 4              5       0.0       3        Allen, Mr. William Henry  male
# 12            13       0.0       3  Saundercock, Mr. William Henry  male
# 159          160       0.0       3      Sage, Master. Thomas Henry  male
# 209          210       1.0       1                Blank, Mr. Henry  male
# 212          213       0.0       3          Perkin, Mr. John Henry  male
#
#       Age  SibSp  Parch     Ticket   Fare Cabin Embarked
# 4    35.0      0      0     373450   8.05   NaN        S
# 12   20.0      0      0  A/5. 2151   8.05   NaN        S
# 159   NaN      8      2   CA. 2343  69.55   NaN        S
# 209  40.0      0      0     112277  31.00   A31        C
# 212  22.0      0      0  A/5 21174   7.25   NaN        S

# %%
index = df[df['Name'].str.contains('Henry$')].index

# %%
df.loc[index, 'Name'].str.replace('Henry', 'Freitas')
# Out:
# 4              Allen, Mr. William Freitas
# 12       Saundercock, Mr. William Freitas
# 159          Sage, Master. Thomas Freitas
# 209                    Blank, Mr. Freitas
# 212              Perkin, Mr. John Freitas
# 222             Green, Mr. George Freitas
# 239              Hunt, Mr. George Freitas
# 271        Tornquist, Mr. William Freitas
# 385           Davies, Mr. Charles Freitas
# 411                     Hart, Mr. Freitas
# 476             Renouf, Mr. Peter Freitas
# 482            Rouse, Mr. Richard Freitas
# 594             Chapman, Mr. John Freitas
# 695          Chapman, Mr. Charles Freitas
# 722        Gillespie, Mr. William Freitas
# 949           Davison, Mr. Thomas Freitas
# 990        Nancarrow, Mr. William Freitas
# 1037        Hilliard, Mr. Herbert Freitas
# 1068    Stengel, Mr. Charles Emil Freitas
# 1251        Sage, Master. William Freitas
# 1290           Conlon, Mr. Thomas Freitas
# Name: Name, dtype: object

# %%
df.loc[index, 'Name'] = df.loc[index, 'Name'].str.replace('Henry', 'Freitas')

# %%
df[df['Name'].str.contains('Freitas$')]
# Out:
#       PassengerId  Survived  Pclass                               Name   Sex  \
# 4               5       0.0       3         Allen, Mr. William Freitas  male
# 12             13       0.0       3   Saundercock, Mr. William Freitas  male
# 159           160       0.0       3       Sage, Master. Thomas Freitas  male
# 209           210       1.0       1                 Blank, Mr. Freitas  male
# 212           213       0.0       3           Perkin, Mr. John Freitas  male
# 222           223       0.0       3          Green, Mr. George Freitas  male
# 239           240       0.0       2           Hunt, Mr. George Freitas  male
# 271           272       1.0       3     Tornquist, Mr. William Freitas  male
# 385           386       0.0       2        Davies, Mr. Charles Freitas  male
# 411           412       0.0       3                  Hart, Mr. Freitas  male
# 476           477       0.0       2          Renouf, Mr. Peter Freitas  male
# 482           483       0.0       3         Rouse, Mr. Richard Freitas  male
# 594           595       0.0       2          Chapman, Mr. John Freitas  male
# 695           696       0.0       2       Chapman, Mr. Charles Freitas  male
# 722           723       0.0       2     Gillespie, Mr. William Freitas  male
# 949           950       NaN       3        Davison, Mr. Thomas Freitas  male
# 990           991       NaN       3     Nancarrow, Mr. William Freitas  male
# 1037         1038       NaN       1      Hilliard, Mr. Herbert Freitas  male
# 1068         1069       NaN       1  Stengel, Mr. Charles Emil Freitas  male
# 1251         1252       NaN       3      Sage, Master. William Freitas  male
# 1290         1291       NaN       3         Conlon, Mr. Thomas Freitas  male
#
#        Age  SibSp  Parch        Ticket     Fare Cabin Embarked
# 4     35.0      0      0        373450   8.0500   NaN        S
# 12    20.0      0      0     A/5. 2151   8.0500   NaN        S
# 159    NaN      8      2      CA. 2343  69.5500   NaN        S
# 209   40.0      0      0        112277  31.0000   A31        C
# 212   22.0      0      0     A/5 21174   7.2500   NaN        S
# 222   51.0      0      0         21440   8.0500   NaN        S
# 239   33.0      0      0    SCO/W 1585  12.2750   NaN        S
# 271   25.0      0      0          LINE   0.0000   NaN        S
# 385   18.0      0      0  S.O.C. 14879  73.5000   NaN        S
# 411    NaN      0      0        394140   6.8583   NaN        Q
# 476   34.0      1      0         31027  21.0000   NaN        S
# 482   50.0      0      0      A/5 3594   8.0500   NaN        S
# 594   37.0      1      0   SC/AH 29037  26.0000   NaN        S
# 695   52.0      0      0        248731  13.5000   NaN        S
# 722   34.0      0      0         12233  13.0000   NaN        S
# 949    NaN      1      0        386525  16.1000   NaN        S
# 990   33.0      0      0    A./5. 3338   8.0500   NaN        S
# 1037   NaN      0      0         17463  51.8625   E46        S
# 1068  54.0      1      0         11778  55.4417  C116        C
# 1251  14.5      8      2      CA. 2343  69.5500   NaN        S
# 1290  31.0      0      0         21332   7.7333   NaN        Q

# %% [markdown]
# ## Para praticar
#
# - https://www.w3schools.com/python/python_regex.asp
# - Filtre pessoas que contém "Mr"
# - Filtre nomes que começam com a palavra "Chapman"
# - Filtre nomes que terminam com a palavra
